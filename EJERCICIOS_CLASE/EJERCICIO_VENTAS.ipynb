# %% [markdown]
# <a href="https://colab.research.google.com/github/claudiaesnarrizaga/UFV-visualizacion/blob/main/EJERCICIOS_CLASE/EJERCICIO_VENTAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Tamaño del dataset
# 2. Nº actuals y forecasts
# 3. Horizonte de predicción (el número de puntos que predices. En este caso es número de meses que predices)
# 4. Número de países y de productos
# 5. Histórico de actuals / forecasts
# 6. Forecasts distintos

# %%
import pandas as pd

# Enlace al archivo CSV en la versión "raw" de GitHub
url = 'https://raw.githubusercontent.com/claudiaesnarrizaga/UFV-visualizacion/refs/heads/main/EJERCICIOS%20CLASE/datos_ejercicio_ventas.csv?token=GHSAT0AAAAAACYZ65SFLHWON6YS7RE32D36ZYSSOCQ'
# Leer el archivo CSV directamente desde GitHub
df = pd.read_csv(url, sep = ';')

# Mostrar las primeras 5 filas del DataFrame
df.head()
# Out:
#          COUNTRY        SUBBRAND  YEAR  MONTH     SCENARIO FORECAST  \
# 0       Portugal     Lipton (L3)  2023     12  AI_forecast  AI_P02F
# 1  Great Britain     Lipton (L3)  2023     12  AI_forecast  AI_P10F
# 2          Spain  Pepsi Max (L3)  2023     12  AI_forecast  AI_P09F
# 3  Great Britain        7up (L3)  2024     12  AI_forecast  AI_P10F
# 4        Hungary     Lipton (L3)  2023      9  AI_forecast  AI_P03F
#
#    FORECAST_YEAR       AMOUNT
# 0         2023.0  7,54356E+15
# 1         2023.0  5,60031E+15
# 2         2023.0   8,8502E+15
# 3         2023.0  3,63225E+15
# 4         2023.0  3,96176E+16

# %%
print("Tamaño del dataset:", df.shape)
# Out:
# Tamaño del dataset: (18666, 8)

# %% [markdown]
# El dataset tiene 18666 filas y 8 columnas.

# %%
# Contar el número de forecasts y actuals en la columna SCENARIO
num_forecasts = df[df['SCENARIO'] == 'AI_forecast'].shape[0]
num_actuals = df[df['SCENARIO'] == 'actual'].shape[0]

# Mostrar resultados
print("Número de forecasts:", num_forecasts)
print("Número de actuals:", num_actuals)
# Out:
# Número de forecasts: 17766
# Número de actuals: 900

# %%
lipton = df[df['SUBBRAND'] == 'Lipton (L3)']
lipton_portugal = lipton[lipton['COUNTRY'] == 'Portugal']
lipton_portugal_ai_forecast = lipton_portugal[lipton_portugal['SCENARIO'] == 'AI_forecast']
lipton_portugal_ai_forecast_P11F = lipton_portugal_ai_forecast[lipton_portugal_ai_forecast['FORECAST'] == 'AI_P11F']
lipton_portugal_ai_forecast_P11F.count()
# Out:
# COUNTRY          18
# SUBBRAND         18
# YEAR             18
# MONTH            18
# SCENARIO         18
# FORECAST         18
# FORECAST_YEAR    18
# AMOUNT           18
# dtype: int64

# %% [markdown]
# Número de países y de productos

# %%
# Contar el número de países únicos
# paises = df['COUNTRY'].unique()
# len(paises)
num_paises = df['COUNTRY'].nunique()

# Contar el número de productos (submarcas) únicos
# productos = df['SUBBRAND'].unique()
# len(productos)
num_productos = df['SUBBRAND'].nunique()

# Mostrar resultados
print("Número de países:", num_paises)
print("Número de productos (submarcas):", num_productos)
# Out:
# Número de países: 9
# Número de productos (submarcas): 6

# %%
# Filtrar por los valores 'Actual' en la columna SCENARIO
actuals = df[df['SCENARIO'] == 'actual']
actuals_ordenado = actuals.sort_values(by=['YEAR', 'MONTH']).reset_index(drop=True)
actuals_ordenado
# Out:
#            COUNTRY            SUBBRAND  YEAR  MONTH SCENARIO FORECAST  \
# 0            Spain      Pepsi Max (L3)  2023      1   actual      NaN
# 1          Hungary            7up (L3)  2023      1   actual      NaN
# 2      Netherlands      Pepsi Max (L3)  2023      1   actual      NaN
# 3           Norway      Pepsi Max (L3)  2023      1   actual      NaN
# 4         Portugal       7up Free (L3)  2023      1   actual      NaN
# ..             ...                 ...   ...    ...      ...      ...
# 895  Great Britain            7up (L3)  2024      8   actual      NaN
# 896         Norway   Mountain Dew (L3)  2024      8   actual      NaN
# 897          Czech  Pepsi Regular (L3)  2024      8   actual      NaN
# 898         Norway         Lipton (L3)  2024      8   actual      NaN
# 899         Norway      Pepsi Max (L3)  2024      8   actual      NaN
#
#      FORECAST_YEAR        AMOUNT
# 0              NaN   8,32741E+15
# 1              NaN   6,46403E+16
# 2              NaN   6,86853E+15
# 3              NaN    2,5217E+15
# 4              NaN   7,20786E+15
# ..             ...           ...
# 895            NaN   3,87428E+14
# 896            NaN   9,11288E+12
# 897            NaN    9,8529E+14
# 898            NaN  -2,43567E+12
# 899            NaN   3,11036E+15
#
# [900 rows x 8 columns]

# %% [markdown]
# El histórico de actuals es de enero de 2023 hasta agosto de 2024.

# %%
# Filtrar por los valores 'AI_Forecast' en la columna SCENARIO
ai = df[df['SCENARIO'] == 'AI_forecast']
ai_ordenado = ai.sort_values(by=['YEAR', 'MONTH']).reset_index(drop=True)
ai_ordenado
# Out:
#              COUNTRY            SUBBRAND  YEAR  MONTH     SCENARIO FORECAST  \
# 0              Czech      Pepsi Max (L3)  2023      1  AI_forecast    AI_PF
# 1            Hungary      Pepsi Max (L3)  2023      1  AI_forecast    AI_PF
# 2           Portugal  Pepsi Regular (L3)  2023      1  AI_forecast    AI_PF
# 3      Great Britain       7up Free (L3)  2023      1  AI_forecast    AI_PF
# 4             Norway            7up (L3)  2023      1  AI_forecast    AI_PF
# ...              ...                 ...   ...    ...          ...      ...
# 17761          Spain      Pepsi Max (L3)  2025      5  AI_forecast  AI_P12F
# 17762  Great Britain       7up Free (L3)  2025      5  AI_forecast  AI_P12F
# 17763  Great Britain       7up Free (L3)  2025      5  AI_forecast  AI_P12F
# 17764         Norway  Pepsi Regular (L3)  2025      5  AI_forecast  AI_P12F
# 17765        Hungary            7up (L3)  2025      5  AI_forecast  AI_P12F
#
#        FORECAST_YEAR       AMOUNT
# 0             2023.0  3,17424E+15
# 1             2023.0  5,05009E+16
# 2             2023.0  1,69246E+16
# 3             2023.0  1,20782E+16
# 4             2023.0   6,6361E+14
# ...              ...          ...
# 17761         2023.0   1,4671E+15
# 17762         2023.0  1,68293E+15
# 17763         2023.0  3,58945E+15
# 17764         2023.0   3,0593E+15
# 17765         2023.0            0
#
# [17766 rows x 8 columns]

# %% [markdown]
# El histórico de ai_forecast (predicciones) es desde enero de 2023 hasta mayo de 2025.

# %% [markdown]
# Como nuestra columna de FORECAST_YEAR solo tiene datos para 2023, entonces no hace falta ver la combinación. Si hubiera FORECAST_YEAR == 2024 entonces lo que tendríamos que hacer es para cada periodo, cuántos se hacen en 2023 y cuántos en 2024. Para eso filtraríamos por cada periodo y contaríamos cuántos se hacen en 2023 y cuántos en 2024.

# %%
forecasts = df['FORECAST'].unique()
forecasts
# Out:
# array(['AI_P02F', 'AI_P10F', 'AI_P09F', 'AI_P03F', 'AI_PF', 'AI_P11F',
#        'AI_P06F', 'AI_P05F', 'AI_P07F', 'AI_P12F', 'AI_P08F', 'AI_P04F',
#        nan], dtype=object)
